# %% [markdown]
# Q1: Who devloped python programming?
#
# Answer: Python was created by Guido van Rossum, and first released on February 20, 1991.
#
# Q2: Which type of programming  does python support?
#
# Answer: Python is a multi-paradigm programming language. Object-oriented programming and structured programming are fully supported, and many of their features support functional programming and aspect-oriented programming
#
# Q3: Is python case sensitive while dealing with identifiers?
#
# Answer:Yes, Python is a case-sensitive language, so identifiers are case-sensitive.
#
# Q4: What is the correct extension of a python file?
#
# Answer: The extensions for Python files are - . py, . pyi, . pyc, .
#
# Q5: Is python code compile or interprited?
#
# Answer: Python is Both Compiled as well as Interpreted
#
# Q6: Name a few blocks of code used to defin python language?
#
# Answer: The following are blocks: a module, a function body, and a class definition.
#
# Q7: State a character used to give a single line comments in python?
#
# Answer: Python offers a pretty simple and straightforward way to write a comment. We can write a single-line comment by adding a single # character before any statement or line of code.
#
# Q8: Mention function of python to identifi version of python that we are currently working on?
#
# Answer: The function sys. version can help us to find the version of python that we are currently working on.
#
# Q9: Python supports the creation of anonymous funtion at runtime, using a construct called :
#
# Answer: lambda.
#
# Q10: What done PIP stands for in python?
#
# Answer: PIP is a recursive acronym for “Preferred Installer Program”
#
# Q11: Mention few in-built functions in python
#
# Answer: Some examples of built-in functions in Python are len(), str(), int(), float(), range(), max(), min(), sum(), open(), sorted(), and type().
#
# Q12: What is the maximum possible length of an identifier?
#
# Answer: Identifiers can be of any length.
#
# Q13: What are the benefits of using python.
#
# Answer:
#
# Presence of third-party modules.
#
# Extensive support libraries(NumPy for numerical calculations, Pandas for data analytics, etc.)
#
# Open source and large active community base.
#
# Versatile, Easy to read, learn and write.
#
# User-friendly data structures.
#
# High-level language.
#
# Q14: How is memory managed in python?
#
# Answer: Memory management in Python involves a private heap containing all Python objects and data structures.
#
# Q15: How to install python in windows and set veriables?
#
# Right click on My Computer and click on properties.
#
# Click on Advanced System settings.
#
# Click on Environment Variable tab.
#
# Click on new tab of user variables.
#
# Write path in variable name.
#
# Copy the path of Python folder.
#
# Paste path of Python in variable value.
#
# Q16: Is indentation required in python?
#
# Answer: Indentation is mandatory in python to define the blocks of statements.
